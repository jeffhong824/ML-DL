# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
from tqdm.auto import tqdm
import imgaug.augmenters as iaa
import imgaug as ia
from tensorflow.keras import *
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
'''
# download dataset from https://drive.google.com/file/d/1JILW10sr40CRTLiuA1mf__5GBtMDF9xc/view?usp=sharing
# !pip install --upgrade gdown
# !gdown --id 1JILW10sr40CRTLiuA1mf__5GBtMDF9xc --output vessel_seg.zip
# unzip file
# !unzip -q vessel_seg.zip
'''
# Out:
# '\n# download dataset from https://drive.google.com/file/d/1JILW10sr40CRTLiuA1mf__5GBtMDF9xc/view?usp=sharing\n!pip install --upgrade gdown\n!gdown --id 1JILW10sr40CRTLiuA1mf__5GBtMDF9xc --output vessel_seg.zip\n# unzip file\n!unzip -q vessel_seg.zip\n'

# %%
# read img and mask
img_paths = glob('/content/drive/MyDrive/all/train/*.tif')
img_path = np.random.choice(img_paths, size=1)[0]
mask_path = img_path.replace('_training.tif', '_manual1.gif')

print('img path: ', img_path)
print('mask path:',  mask_path)

img = cv2.imread(img_path)[:, :, ::-1]
mask = Image.open(mask_path)
mask = np.array(mask)
# Out:
# img path:  /content/drive/MyDrive/all/train/26_training.tif
# mask path: /content/drive/MyDrive/all/train/26_manual1.gif

# %%
# show image
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(mask)
plt.show()

# %%
img.shape, mask.shape
# Out:
# ((584, 565, 3), (584, 565))

# %%
IMG_SIZE = 512
BS = 4

# %%
class DataGenerator(utils.Sequence):
    def __init__(self, img_paths, batch_size, img_size, shuffle=True, mode='train', aug=False):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.img_size = img_size
        self.mode = mode
        self.img_paths = img_paths
        self.mask_paths = [p.replace('_training.tif', '_manual1.gif') for p in self.img_paths]
        self.aug = aug
        self.seq = iaa.Sequential([
            iaa.Fliplr(0.5), # 50% horizontal flip
            iaa.Affine(
                rotate=(-10, 10), # random rotate -45 ~ +45 degree
                shear=(-16,16), # random shear -16 ~ +16 degree
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)} # scale x, y: 80%~120%
            ),
        ])
        self.indexes = np.arange(len(self.mask_paths))
        # data augmentation
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.mask_paths) / self.batch_size)) # batches per epoch

    def __getitem__(self, index):
        # Generate indexes of the batch
        idxs = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        # Find list of IDs
        batch_img_paths = [self.img_paths[i] for i in idxs]
        batch_mask_paths = [self.mask_paths[i] for i in idxs]

        # Generate data
        X, y = self.__data_generation(batch_img_paths, batch_mask_paths)
        if self.mode != 'test':
            return X, y
        else:
            return X

    def on_epoch_end(self):
        # Updates indexes after each epoch
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, img_paths, mask_paths):
        # Generates data containing batch_size samples
        x = np.empty((len(img_paths), self.img_size, self.img_size, 3), dtype=np.float32)
        y = np.empty((len(img_paths), self.img_size, self.img_size, 1), dtype=np.float32)

        for i, (img_path, mask_path) in enumerate(zip(img_paths, mask_paths)):
            img = cv2.imread(img_path)[:, :,::-1]
            img = self.preprocess(img)
            x[i] = img
            if self.mode != 'test':
                mask = np.array(Image.open(mask_path))
                mask = self.preprocess(mask)
                y[i] = np.expand_dims(mask, axis=-1)
        if self.aug:
          x, y = self.seq(images=x, heatmaps=y)
        return x, y

    def preprocess(self, img):
        data = cv2.resize(img, (self.img_size, self.img_size))
        data = data / 255. # normalize to 0~1
        return data

# %%
all_paths = glob('/content/drive/MyDrive/all/train/*.tif')
test_paths = sorted(glob('/content/drive/MyDrive/all/test/*.tif'))
train_paths, val_paths = train_test_split(all_paths, test_size=0.2)

train_gen = DataGenerator(train_paths, BS, IMG_SIZE, shuffle=True, mode='train', aug=True)
val_gen = DataGenerator(val_paths, BS, IMG_SIZE, shuffle=False, mode='val')
test_gen = DataGenerator(test_paths, BS, IMG_SIZE, shuffle=False, mode='test')

# %%
# Check output

batch_x, batch_y = train_gen[0]

batch_i = np.random.choice(len(batch_x))
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(batch_x[batch_i], cmap='gray')
plt.subplot(1,2,2)
plt.imshow(batch_y[batch_i, :, :, 0])
plt.show()

# %%
input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
c1 = layers.Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same')(input_layer)
l = layers.MaxPool2D(strides=(2,2))(c1)
c2 = layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same')(l)
l = layers.MaxPool2D(strides=(2,2))(c2)
c3 = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l)
l = layers.MaxPool2D(strides=(2,2))(c3)
c4 = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(l)

l = layers.concatenate([layers.UpSampling2D(size=(2,2))(c4), c3], axis=-1)
l = layers.Conv2D(filters=32, kernel_size=(2,2), activation='relu', padding='same')(l)
l = layers.concatenate([layers.UpSampling2D(size=(2,2))(l), c2], axis=-1)
l = layers.Conv2D(filters=24, kernel_size=(2,2), activation='relu', padding='same')(l)
l = layers.concatenate([layers.UpSampling2D(size=(2,2))(l), c1], axis=-1)
l = layers.Conv2D(filters=16, kernel_size=(2,2), activation='relu', padding='same')(l)
l = layers.Conv2D(filters=64, kernel_size=(1,1), activation='relu')(l)
output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(l)
                                                         
model = models.Model(input_layer, output_layer)

# %%
utils.plot_model(model, show_shapes=True)

# %%
# Customize Dice coefficient
def dice_coef(y_true, y_pred):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
model.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=[dice_coef])

# %%
weight_saver = callbacks.ModelCheckpoint('/content/drive/MyDrive/seg.h5', monitor='val_dice_coef', mode='max', save_best_only=True)

# %%
model.load_weights('/content/drive/MyDrive/seg.h5')

# %%
logs = model.fit(train_gen,
  validation_data = val_gen,
  epochs=500,
  callbacks = [weight_saver])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0990 - dice_coef: 0.6706 - val_loss: 0.0988 - val_dice_coef: 0.6690
# Epoch 2/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0973 - dice_coef: 0.6592 - val_loss: 0.0951 - val_dice_coef: 0.6750
# Epoch 3/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0956 - dice_coef: 0.6727 - val_loss: 0.0956 - val_dice_coef: 0.6761
# Epoch 4/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0938 - dice_coef: 0.6655 - val_loss: 0.0957 - val_dice_coef: 0.6682
# Epoch 5/500
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0954 - dice_coef: 0.6618 - val_loss: 0.1008 - val_dice_coef: 0.6692
# Epoch 6/500
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1008 - dice_coef: 0.6726 - val_loss: 0.0944 - val_dice_coef: 0.6816
# Epoch 7/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0932 - dice_coef: 0.6676 - val_loss: 0.0987 - val_dice_coef: 0.6666
# Epoch 8/500
# 4/4 [==============================] - 1s 325ms/step - loss: 0.1010 - dice_coef: 0.6742 - val_loss: 0.0938 - val_dice_coef: 0.6922
# Epoch 9/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1013 - dice_coef: 0.6751 - val_loss: 0.1025 - val_dice_coef: 0.6591
# Epoch 10/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1016 - dice_coef: 0.6665 - val_loss: 0.0931 - val_dice_coef: 0.6843
# Epoch 11/500
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0945 - dice_coef: 0.6726 - val_loss: 0.0970 - val_dice_coef: 0.6785
# Epoch 12/500
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1010 - dice_coef: 0.6637 - val_loss: 0.0937 - val_dice_coef: 0.6751
# Epoch 13/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0999 - dice_coef: 0.6669 - val_loss: 0.1012 - val_dice_coef: 0.6736
# Epoch 14/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0987 - dice_coef: 0.6745 - val_loss: 0.0944 - val_dice_coef: 0.6856
# Epoch 15/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0956 - dice_coef: 0.6613 - val_loss: 0.1005 - val_dice_coef: 0.6581
# Epoch 16/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1051 - dice_coef: 0.6675 - val_loss: 0.0989 - val_dice_coef: 0.6761
# Epoch 17/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1040 - dice_coef: 0.6699 - val_loss: 0.0939 - val_dice_coef: 0.6778
# Epoch 18/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0955 - dice_coef: 0.6606 - val_loss: 0.1025 - val_dice_coef: 0.6507
# Epoch 19/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0988 - dice_coef: 0.6590 - val_loss: 0.0950 - val_dice_coef: 0.6843
# Epoch 20/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0985 - dice_coef: 0.6740 - val_loss: 0.0959 - val_dice_coef: 0.6821
# Epoch 21/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1010 - dice_coef: 0.6653 - val_loss: 0.0961 - val_dice_coef: 0.6630
# Epoch 22/500
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0937 - dice_coef: 0.6577 - val_loss: 0.0967 - val_dice_coef: 0.6723
# Epoch 23/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0956 - dice_coef: 0.6743 - val_loss: 0.0951 - val_dice_coef: 0.6898
# Epoch 24/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0966 - dice_coef: 0.6707 - val_loss: 0.0999 - val_dice_coef: 0.6613
# Epoch 25/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0917 - dice_coef: 0.6645 - val_loss: 0.0944 - val_dice_coef: 0.6803
# Epoch 26/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0993 - dice_coef: 0.6719 - val_loss: 0.0965 - val_dice_coef: 0.6755
# Epoch 27/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0994 - dice_coef: 0.6705 - val_loss: 0.0969 - val_dice_coef: 0.6733
# Epoch 28/500
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0989 - dice_coef: 0.6743 - val_loss: 0.0958 - val_dice_coef: 0.6765
# Epoch 29/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1036 - dice_coef: 0.6680 - val_loss: 0.0943 - val_dice_coef: 0.6830
# Epoch 30/500
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0943 - dice_coef: 0.6740 - val_loss: 0.0988 - val_dice_coef: 0.6683
# Epoch 31/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1015 - dice_coef: 0.6657 - val_loss: 0.0950 - val_dice_coef: 0.6760
# Epoch 32/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0985 - dice_coef: 0.6658 - val_loss: 0.0970 - val_dice_coef: 0.6755
# Epoch 33/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1046 - dice_coef: 0.6745 - val_loss: 0.1018 - val_dice_coef: 0.6688
# Epoch 34/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0951 - dice_coef: 0.6707 - val_loss: 0.0938 - val_dice_coef: 0.6732
# Epoch 35/500
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1012 - dice_coef: 0.6658 - val_loss: 0.1016 - val_dice_coef: 0.6702
# Epoch 36/500
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0968 - dice_coef: 0.6699 - val_loss: 0.0933 - val_dice_coef: 0.6803
# Epoch 37/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1036 - dice_coef: 0.6606 - val_loss: 0.0996 - val_dice_coef: 0.6688
# Epoch 38/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1002 - dice_coef: 0.6723 - val_loss: 0.0948 - val_dice_coef: 0.6842
# Epoch 39/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1014 - dice_coef: 0.6669 - val_loss: 0.0977 - val_dice_coef: 0.6662
# Epoch 40/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0991 - dice_coef: 0.6643 - val_loss: 0.0967 - val_dice_coef: 0.6769
# Epoch 41/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0880 - dice_coef: 0.6703 - val_loss: 0.0953 - val_dice_coef: 0.6695
# Epoch 42/500
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1038 - dice_coef: 0.6609 - val_loss: 0.1023 - val_dice_coef: 0.6627
# Epoch 43/500
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1003 - dice_coef: 0.6767 - val_loss: 0.0947 - val_dice_coef: 0.6911
# Epoch 44/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0901 - dice_coef: 0.6730 - val_loss: 0.0957 - val_dice_coef: 0.6651
# Epoch 45/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0980 - dice_coef: 0.6606 - val_loss: 0.0987 - val_dice_coef: 0.6735
# Epoch 46/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0995 - dice_coef: 0.6752 - val_loss: 0.0963 - val_dice_coef: 0.6819
# Epoch 47/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0918 - dice_coef: 0.6705 - val_loss: 0.0962 - val_dice_coef: 0.6688
# Epoch 48/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1006 - dice_coef: 0.6682 - val_loss: 0.0986 - val_dice_coef: 0.6766
# Epoch 49/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0991 - dice_coef: 0.6786 - val_loss: 0.0960 - val_dice_coef: 0.6839
# Epoch 50/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0970 - dice_coef: 0.6713 - val_loss: 0.0977 - val_dice_coef: 0.6638
# Epoch 51/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0996 - dice_coef: 0.6607 - val_loss: 0.0941 - val_dice_coef: 0.6823
# Epoch 52/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.1022 - dice_coef: 0.6744 - val_loss: 0.0973 - val_dice_coef: 0.6829
# Epoch 53/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1055 - dice_coef: 0.6755 - val_loss: 0.0942 - val_dice_coef: 0.6800
# Epoch 54/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0975 - dice_coef: 0.6651 - val_loss: 0.0979 - val_dice_coef: 0.6656
# Epoch 55/500
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0996 - dice_coef: 0.6709 - val_loss: 0.0957 - val_dice_coef: 0.6926
# Epoch 56/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0941 - dice_coef: 0.6759 - val_loss: 0.1007 - val_dice_coef: 0.6599
# Epoch 57/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0926 - dice_coef: 0.6591 - val_loss: 0.0932 - val_dice_coef: 0.6773
# Epoch 58/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1032 - dice_coef: 0.6711 - val_loss: 0.1079 - val_dice_coef: 0.6609
# Epoch 59/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0982 - dice_coef: 0.6710 - val_loss: 0.0945 - val_dice_coef: 0.6772
# Epoch 60/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0958 - dice_coef: 0.6588 - val_loss: 0.1016 - val_dice_coef: 0.6606
# Epoch 61/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0994 - dice_coef: 0.6672 - val_loss: 0.0937 - val_dice_coef: 0.6887
# Epoch 62/500
# 4/4 [==============================] - 1s 305ms/step - loss: 0.1021 - dice_coef: 0.6739 - val_loss: 0.0971 - val_dice_coef: 0.6772
# Epoch 63/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1018 - dice_coef: 0.6650 - val_loss: 0.0956 - val_dice_coef: 0.6758
# Epoch 64/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0983 - dice_coef: 0.6560 - val_loss: 0.0967 - val_dice_coef: 0.6716
# Epoch 65/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0911 - dice_coef: 0.6651 - val_loss: 0.0961 - val_dice_coef: 0.6796
# Epoch 66/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0954 - dice_coef: 0.6729 - val_loss: 0.0960 - val_dice_coef: 0.6768
# Epoch 67/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1024 - dice_coef: 0.6688 - val_loss: 0.0968 - val_dice_coef: 0.6769
# Epoch 68/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0983 - dice_coef: 0.6639 - val_loss: 0.0955 - val_dice_coef: 0.6751
# Epoch 69/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1050 - dice_coef: 0.6730 - val_loss: 0.0984 - val_dice_coef: 0.6820
# Epoch 70/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0943 - dice_coef: 0.6757 - val_loss: 0.0944 - val_dice_coef: 0.6745
# Epoch 71/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0993 - dice_coef: 0.6597 - val_loss: 0.0991 - val_dice_coef: 0.6671
# Epoch 72/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1060 - dice_coef: 0.6730 - val_loss: 0.0938 - val_dice_coef: 0.6914
# Epoch 73/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0976 - dice_coef: 0.6732 - val_loss: 0.0991 - val_dice_coef: 0.6679
# Epoch 74/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0954 - dice_coef: 0.6664 - val_loss: 0.0961 - val_dice_coef: 0.6773
# Epoch 75/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1009 - dice_coef: 0.6712 - val_loss: 0.0955 - val_dice_coef: 0.6828
# Epoch 76/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0970 - dice_coef: 0.6757 - val_loss: 0.0955 - val_dice_coef: 0.6785
# Epoch 77/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0984 - dice_coef: 0.6703 - val_loss: 0.0961 - val_dice_coef: 0.6790
# Epoch 78/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0955 - dice_coef: 0.6751 - val_loss: 0.0962 - val_dice_coef: 0.6781
# Epoch 79/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0937 - dice_coef: 0.6720 - val_loss: 0.0953 - val_dice_coef: 0.6812
# Epoch 80/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0961 - dice_coef: 0.6728 - val_loss: 0.0984 - val_dice_coef: 0.6698
# Epoch 81/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0963 - dice_coef: 0.6696 - val_loss: 0.0938 - val_dice_coef: 0.6790
# Epoch 82/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1048 - dice_coef: 0.6726 - val_loss: 0.0990 - val_dice_coef: 0.6731
# Epoch 83/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0991 - dice_coef: 0.6665 - val_loss: 0.0938 - val_dice_coef: 0.6816
# Epoch 84/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1055 - dice_coef: 0.6647 - val_loss: 0.1043 - val_dice_coef: 0.6548
# Epoch 85/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0969 - dice_coef: 0.6687 - val_loss: 0.0949 - val_dice_coef: 0.6798
# Epoch 86/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1014 - dice_coef: 0.6681 - val_loss: 0.0982 - val_dice_coef: 0.6778
# Epoch 87/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1003 - dice_coef: 0.6708 - val_loss: 0.0951 - val_dice_coef: 0.6707
# Epoch 88/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1047 - dice_coef: 0.6631 - val_loss: 0.1034 - val_dice_coef: 0.6658
# Epoch 89/500
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0987 - dice_coef: 0.6729 - val_loss: 0.0934 - val_dice_coef: 0.6861
# Epoch 90/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1008 - dice_coef: 0.6636 - val_loss: 0.1003 - val_dice_coef: 0.6542
# Epoch 91/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1000 - dice_coef: 0.6606 - val_loss: 0.0929 - val_dice_coef: 0.6835
# Epoch 92/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1036 - dice_coef: 0.6711 - val_loss: 0.1023 - val_dice_coef: 0.6701
# Epoch 93/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1032 - dice_coef: 0.6690 - val_loss: 0.0955 - val_dice_coef: 0.6698
# Epoch 94/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0998 - dice_coef: 0.6548 - val_loss: 0.0959 - val_dice_coef: 0.6724
# Epoch 95/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1004 - dice_coef: 0.6713 - val_loss: 0.0958 - val_dice_coef: 0.6846
# Epoch 96/500
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0972 - dice_coef: 0.6747 - val_loss: 0.0986 - val_dice_coef: 0.6756
# Epoch 97/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0999 - dice_coef: 0.6695 - val_loss: 0.0966 - val_dice_coef: 0.6717
# Epoch 98/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0995 - dice_coef: 0.6682 - val_loss: 0.0966 - val_dice_coef: 0.6769
# Epoch 99/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0963 - dice_coef: 0.6691 - val_loss: 0.0968 - val_dice_coef: 0.6764
# Epoch 100/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0987 - dice_coef: 0.6726 - val_loss: 0.0968 - val_dice_coef: 0.6738
# Epoch 101/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0942 - dice_coef: 0.6679 - val_loss: 0.0949 - val_dice_coef: 0.6784
# Epoch 102/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0940 - dice_coef: 0.6731 - val_loss: 0.0972 - val_dice_coef: 0.6733
# Epoch 103/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0998 - dice_coef: 0.6713 - val_loss: 0.0953 - val_dice_coef: 0.6839
# Epoch 104/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0911 - dice_coef: 0.6750 - val_loss: 0.0944 - val_dice_coef: 0.6828
# Epoch 105/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0947 - dice_coef: 0.6758 - val_loss: 0.0970 - val_dice_coef: 0.6780
# Epoch 106/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1018 - dice_coef: 0.6696 - val_loss: 0.0970 - val_dice_coef: 0.6725
# Epoch 107/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1036 - dice_coef: 0.6739 - val_loss: 0.0950 - val_dice_coef: 0.6839
# Epoch 108/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0972 - dice_coef: 0.6741 - val_loss: 0.0979 - val_dice_coef: 0.6684
# Epoch 109/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0935 - dice_coef: 0.6689 - val_loss: 0.0937 - val_dice_coef: 0.6832
# Epoch 110/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0976 - dice_coef: 0.6712 - val_loss: 0.0986 - val_dice_coef: 0.6728
# Epoch 111/500
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0970 - dice_coef: 0.6732 - val_loss: 0.0953 - val_dice_coef: 0.6753
# Epoch 112/500
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0976 - dice_coef: 0.6690 - val_loss: 0.0973 - val_dice_coef: 0.6731
# Epoch 113/500
# 4/4 [==============================] - 1s 304ms/step - loss: 0.1010 - dice_coef: 0.6721 - val_loss: 0.0944 - val_dice_coef: 0.6885
# Epoch 114/500
# 4/4 [==============================] - 1s 302ms/step - loss: 0.0970 - dice_coef: 0.6748 - val_loss: 0.0963 - val_dice_coef: 0.6677
# Epoch 115/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0986 - dice_coef: 0.6665 - val_loss: 0.0974 - val_dice_coef: 0.6757
# Epoch 116/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0955 - dice_coef: 0.6746 - val_loss: 0.0951 - val_dice_coef: 0.6800
# Epoch 117/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0966 - dice_coef: 0.6699 - val_loss: 0.0944 - val_dice_coef: 0.6774
# Epoch 118/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0986 - dice_coef: 0.6707 - val_loss: 0.0975 - val_dice_coef: 0.6778
# Epoch 119/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0967 - dice_coef: 0.6751 - val_loss: 0.0960 - val_dice_coef: 0.6797
# Epoch 120/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0960 - dice_coef: 0.6735 - val_loss: 0.0972 - val_dice_coef: 0.6694
# Epoch 121/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0941 - dice_coef: 0.6671 - val_loss: 0.0953 - val_dice_coef: 0.6806
# Epoch 122/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0928 - dice_coef: 0.6740 - val_loss: 0.0953 - val_dice_coef: 0.6837
# Epoch 123/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1021 - dice_coef: 0.6726 - val_loss: 0.0983 - val_dice_coef: 0.6684
# Epoch 124/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0950 - dice_coef: 0.6687 - val_loss: 0.0939 - val_dice_coef: 0.6861
# Epoch 125/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1032 - dice_coef: 0.6743 - val_loss: 0.1011 - val_dice_coef: 0.6670
# Epoch 126/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1003 - dice_coef: 0.6719 - val_loss: 0.0935 - val_dice_coef: 0.6818
# Epoch 127/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0942 - dice_coef: 0.6711 - val_loss: 0.0980 - val_dice_coef: 0.6719
# Epoch 128/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0995 - dice_coef: 0.6718 - val_loss: 0.0943 - val_dice_coef: 0.6844
# Epoch 129/500
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0906 - dice_coef: 0.6732 - val_loss: 0.0954 - val_dice_coef: 0.6804
# Epoch 130/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0997 - dice_coef: 0.6703 - val_loss: 0.0971 - val_dice_coef: 0.6729
# Epoch 131/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1029 - dice_coef: 0.6737 - val_loss: 0.0939 - val_dice_coef: 0.6884
# Epoch 132/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0959 - dice_coef: 0.6694 - val_loss: 0.1005 - val_dice_coef: 0.6590
# Epoch 133/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1024 - dice_coef: 0.6616 - val_loss: 0.0937 - val_dice_coef: 0.6897
# Epoch 134/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1063 - dice_coef: 0.6730 - val_loss: 0.1009 - val_dice_coef: 0.6640
# Epoch 135/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0955 - dice_coef: 0.6604 - val_loss: 0.0935 - val_dice_coef: 0.6834
# Epoch 136/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0968 - dice_coef: 0.6664 - val_loss: 0.1025 - val_dice_coef: 0.6622
# Epoch 137/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1024 - dice_coef: 0.6616 - val_loss: 0.0940 - val_dice_coef: 0.6828
# Epoch 138/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1042 - dice_coef: 0.6587 - val_loss: 0.0953 - val_dice_coef: 0.6797
# Epoch 139/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0962 - dice_coef: 0.6640 - val_loss: 0.0969 - val_dice_coef: 0.6696
# Epoch 140/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0962 - dice_coef: 0.6654 - val_loss: 0.0960 - val_dice_coef: 0.6819
# Epoch 141/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1072 - dice_coef: 0.6722 - val_loss: 0.0999 - val_dice_coef: 0.6646
# Epoch 142/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0993 - dice_coef: 0.6611 - val_loss: 0.0960 - val_dice_coef: 0.6763
# Epoch 143/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.1006 - dice_coef: 0.6747 - val_loss: 0.0968 - val_dice_coef: 0.6858
# Epoch 144/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0911 - dice_coef: 0.6745 - val_loss: 0.0951 - val_dice_coef: 0.6775
# Epoch 145/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0940 - dice_coef: 0.6599 - val_loss: 0.0993 - val_dice_coef: 0.6583
# Epoch 146/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1081 - dice_coef: 0.6639 - val_loss: 0.0970 - val_dice_coef: 0.6849
# Epoch 147/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0977 - dice_coef: 0.6829 - val_loss: 0.0982 - val_dice_coef: 0.6777
# Epoch 148/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.1016 - dice_coef: 0.6744 - val_loss: 0.0950 - val_dice_coef: 0.6812
# Epoch 149/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1000 - dice_coef: 0.6669 - val_loss: 0.0974 - val_dice_coef: 0.6708
# Epoch 150/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0959 - dice_coef: 0.6717 - val_loss: 0.0944 - val_dice_coef: 0.6804
# Epoch 151/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1011 - dice_coef: 0.6772 - val_loss: 0.1000 - val_dice_coef: 0.6727
# Epoch 152/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0980 - dice_coef: 0.6705 - val_loss: 0.0933 - val_dice_coef: 0.6799
# Epoch 153/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0959 - dice_coef: 0.6703 - val_loss: 0.0996 - val_dice_coef: 0.6736
# Epoch 154/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0972 - dice_coef: 0.6751 - val_loss: 0.0932 - val_dice_coef: 0.6832
# Epoch 155/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0942 - dice_coef: 0.6663 - val_loss: 0.0958 - val_dice_coef: 0.6737
# Epoch 156/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1012 - dice_coef: 0.6720 - val_loss: 0.0955 - val_dice_coef: 0.6847
# Epoch 157/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0899 - dice_coef: 0.6739 - val_loss: 0.0943 - val_dice_coef: 0.6713
# Epoch 158/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1038 - dice_coef: 0.6677 - val_loss: 0.1012 - val_dice_coef: 0.6756
# Epoch 159/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1011 - dice_coef: 0.6781 - val_loss: 0.0939 - val_dice_coef: 0.6764
# Epoch 160/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.1073 - dice_coef: 0.6626 - val_loss: 0.0965 - val_dice_coef: 0.6789
# Epoch 161/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0985 - dice_coef: 0.6775 - val_loss: 0.0956 - val_dice_coef: 0.6797
# Epoch 162/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0969 - dice_coef: 0.6676 - val_loss: 0.0955 - val_dice_coef: 0.6580
# Epoch 163/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0986 - dice_coef: 0.6568 - val_loss: 0.0962 - val_dice_coef: 0.6777
# Epoch 164/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.1011 - dice_coef: 0.6764 - val_loss: 0.1009 - val_dice_coef: 0.6728
# Epoch 165/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0953 - dice_coef: 0.6673 - val_loss: 0.0928 - val_dice_coef: 0.6737
# Epoch 166/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1048 - dice_coef: 0.6604 - val_loss: 0.1067 - val_dice_coef: 0.6539
# Epoch 167/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1035 - dice_coef: 0.6645 - val_loss: 0.0956 - val_dice_coef: 0.6835
# Epoch 168/500
# 4/4 [==============================] - 1s 302ms/step - loss: 0.0995 - dice_coef: 0.6638 - val_loss: 0.0938 - val_dice_coef: 0.6728
# Epoch 169/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0987 - dice_coef: 0.6603 - val_loss: 0.0958 - val_dice_coef: 0.6701
# Epoch 170/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0964 - dice_coef: 0.6676 - val_loss: 0.0939 - val_dice_coef: 0.6875
# Epoch 171/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0964 - dice_coef: 0.6683 - val_loss: 0.0979 - val_dice_coef: 0.6715
# Epoch 172/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0971 - dice_coef: 0.6628 - val_loss: 0.0932 - val_dice_coef: 0.6767
# Epoch 173/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0913 - dice_coef: 0.6674 - val_loss: 0.0996 - val_dice_coef: 0.6700
# Epoch 174/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0994 - dice_coef: 0.6717 - val_loss: 0.0938 - val_dice_coef: 0.6827
# Epoch 175/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0971 - dice_coef: 0.6684 - val_loss: 0.0965 - val_dice_coef: 0.6752
# Epoch 176/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0999 - dice_coef: 0.6757 - val_loss: 0.0948 - val_dice_coef: 0.6819
# Epoch 177/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0948 - dice_coef: 0.6699 - val_loss: 0.0959 - val_dice_coef: 0.6722
# Epoch 178/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0981 - dice_coef: 0.6676 - val_loss: 0.0958 - val_dice_coef: 0.6807
# Epoch 179/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0976 - dice_coef: 0.6768 - val_loss: 0.0945 - val_dice_coef: 0.6822
# Epoch 180/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.1002 - dice_coef: 0.6749 - val_loss: 0.0982 - val_dice_coef: 0.6707
# Epoch 181/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1024 - dice_coef: 0.6733 - val_loss: 0.0937 - val_dice_coef: 0.6858
# Epoch 182/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0981 - dice_coef: 0.6722 - val_loss: 0.0979 - val_dice_coef: 0.6643
# Epoch 183/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0985 - dice_coef: 0.6605 - val_loss: 0.0976 - val_dice_coef: 0.6716
# Epoch 184/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0945 - dice_coef: 0.6742 - val_loss: 0.0966 - val_dice_coef: 0.6760
# Epoch 185/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0968 - dice_coef: 0.6698 - val_loss: 0.0968 - val_dice_coef: 0.6733
# Epoch 186/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.1011 - dice_coef: 0.6739 - val_loss: 0.0946 - val_dice_coef: 0.6882
# Epoch 187/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0984 - dice_coef: 0.6761 - val_loss: 0.0979 - val_dice_coef: 0.6678
# Epoch 188/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0929 - dice_coef: 0.6654 - val_loss: 0.0949 - val_dice_coef: 0.6787
# Epoch 189/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0970 - dice_coef: 0.6778 - val_loss: 0.0955 - val_dice_coef: 0.6801
# Epoch 190/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0942 - dice_coef: 0.6707 - val_loss: 0.0961 - val_dice_coef: 0.6720
# Epoch 191/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0907 - dice_coef: 0.6703 - val_loss: 0.0945 - val_dice_coef: 0.6815
# Epoch 192/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0959 - dice_coef: 0.6756 - val_loss: 0.0957 - val_dice_coef: 0.6789
# Epoch 193/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0945 - dice_coef: 0.6750 - val_loss: 0.0945 - val_dice_coef: 0.6808
# Epoch 194/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0936 - dice_coef: 0.6712 - val_loss: 0.0949 - val_dice_coef: 0.6789
# Epoch 195/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0974 - dice_coef: 0.6738 - val_loss: 0.0967 - val_dice_coef: 0.6776
# Epoch 196/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0985 - dice_coef: 0.6761 - val_loss: 0.0965 - val_dice_coef: 0.6788
# Epoch 197/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0995 - dice_coef: 0.6768 - val_loss: 0.0945 - val_dice_coef: 0.6826
# Epoch 198/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0920 - dice_coef: 0.6741 - val_loss: 0.0966 - val_dice_coef: 0.6687
# Epoch 199/500
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0956 - dice_coef: 0.6701 - val_loss: 0.0951 - val_dice_coef: 0.6862
# Epoch 200/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0932 - dice_coef: 0.6736 - val_loss: 0.0983 - val_dice_coef: 0.6675
# Epoch 201/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0987 - dice_coef: 0.6614 - val_loss: 0.0945 - val_dice_coef: 0.6815
# Epoch 202/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.1011 - dice_coef: 0.6772 - val_loss: 0.0976 - val_dice_coef: 0.6756
# Epoch 203/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1037 - dice_coef: 0.6721 - val_loss: 0.1018 - val_dice_coef: 0.6608
# Epoch 204/500
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0976 - dice_coef: 0.6661 - val_loss: 0.0946 - val_dice_coef: 0.6842
# Epoch 205/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0994 - dice_coef: 0.6763 - val_loss: 0.0973 - val_dice_coef: 0.6746
# Epoch 206/500
# 4/4 [==============================] - 1s 307ms/step - loss: 0.0977 - dice_coef: 0.6707 - val_loss: 0.0969 - val_dice_coef: 0.6718
# Epoch 207/500
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0924 - dice_coef: 0.6692 - val_loss: 0.0958 - val_dice_coef: 0.6789
# Epoch 208/500
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0981 - dice_coef: 0.6758 - val_loss: 0.0943 - val_dice_coef: 0.6810
# Epoch 209/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0990 - dice_coef: 0.6723 - val_loss: 0.0993 - val_dice_coef: 0.6713
# Epoch 210/500
# 4/4 [==============================] - 1s 305ms/step - loss: 0.1002 - dice_coef: 0.6705 - val_loss: 0.0921 - val_dice_coef: 0.6831
# Epoch 211/500
# 4/4 [==============================] - 1s 308ms/step - loss: 0.1010 - dice_coef: 0.6652 - val_loss: 0.1092 - val_dice_coef: 0.6469
# Epoch 212/500
# 4/4 [==============================] - 1s 305ms/step - loss: 0.0980 - dice_coef: 0.6702 - val_loss: 0.0939 - val_dice_coef: 0.6882
# Epoch 213/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0998 - dice_coef: 0.6666 - val_loss: 0.1039 - val_dice_coef: 0.6536
# Epoch 214/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.1023 - dice_coef: 0.6579 - val_loss: 0.0940 - val_dice_coef: 0.6808
# Epoch 215/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.1003 - dice_coef: 0.6664 - val_loss: 0.0993 - val_dice_coef: 0.6709
# Epoch 216/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0984 - dice_coef: 0.6699 - val_loss: 0.0957 - val_dice_coef: 0.6753
# Epoch 217/500
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0980 - dice_coef: 0.6689 - val_loss: 0.0953 - val_dice_coef: 0.6739
# Epoch 218/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0987 - dice_coef: 0.6727 - val_loss: 0.0973 - val_dice_coef: 0.6828
# Epoch 219/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1008 - dice_coef: 0.6737 - val_loss: 0.0945 - val_dice_coef: 0.6794
# Epoch 220/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1030 - dice_coef: 0.6704 - val_loss: 0.0947 - val_dice_coef: 0.6794
# Epoch 221/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0980 - dice_coef: 0.6732 - val_loss: 0.0957 - val_dice_coef: 0.6802
# Epoch 222/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0942 - dice_coef: 0.6746 - val_loss: 0.0957 - val_dice_coef: 0.6739
# Epoch 223/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0993 - dice_coef: 0.6655 - val_loss: 0.0986 - val_dice_coef: 0.6697
# Epoch 224/500
# 4/4 [==============================] - 1s 305ms/step - loss: 0.1036 - dice_coef: 0.6728 - val_loss: 0.0943 - val_dice_coef: 0.6846
# Epoch 225/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0901 - dice_coef: 0.6773 - val_loss: 0.0943 - val_dice_coef: 0.6763
# Epoch 226/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0944 - dice_coef: 0.6693 - val_loss: 0.0950 - val_dice_coef: 0.6765
# Epoch 227/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0941 - dice_coef: 0.6717 - val_loss: 0.0939 - val_dice_coef: 0.6855
# Epoch 228/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0978 - dice_coef: 0.6779 - val_loss: 0.0976 - val_dice_coef: 0.6756
# Epoch 229/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0992 - dice_coef: 0.6708 - val_loss: 0.0946 - val_dice_coef: 0.6782
# Epoch 230/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0994 - dice_coef: 0.6764 - val_loss: 0.0976 - val_dice_coef: 0.6815
# Epoch 231/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0974 - dice_coef: 0.6760 - val_loss: 0.0943 - val_dice_coef: 0.6774
# Epoch 232/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.1066 - dice_coef: 0.6716 - val_loss: 0.0953 - val_dice_coef: 0.6805
# Epoch 233/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0955 - dice_coef: 0.6770 - val_loss: 0.0963 - val_dice_coef: 0.6792
# Epoch 234/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0983 - dice_coef: 0.6724 - val_loss: 0.0949 - val_dice_coef: 0.6799
# Epoch 235/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0962 - dice_coef: 0.6730 - val_loss: 0.0975 - val_dice_coef: 0.6762
# Epoch 236/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0977 - dice_coef: 0.6738 - val_loss: 0.0938 - val_dice_coef: 0.6817
# Epoch 237/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0962 - dice_coef: 0.6758 - val_loss: 0.0991 - val_dice_coef: 0.6759
# Epoch 238/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0973 - dice_coef: 0.6765 - val_loss: 0.0939 - val_dice_coef: 0.6781
# Epoch 239/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0976 - dice_coef: 0.6682 - val_loss: 0.0964 - val_dice_coef: 0.6775
# Epoch 240/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0977 - dice_coef: 0.6707 - val_loss: 0.0964 - val_dice_coef: 0.6750
# Epoch 241/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0932 - dice_coef: 0.6744 - val_loss: 0.0949 - val_dice_coef: 0.6797
# Epoch 242/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0992 - dice_coef: 0.6783 - val_loss: 0.0972 - val_dice_coef: 0.6776
# Epoch 243/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0976 - dice_coef: 0.6742 - val_loss: 0.0938 - val_dice_coef: 0.6801
# Epoch 244/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0954 - dice_coef: 0.6694 - val_loss: 0.0945 - val_dice_coef: 0.6809
# Epoch 245/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0977 - dice_coef: 0.6755 - val_loss: 0.0977 - val_dice_coef: 0.6745
# Epoch 246/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1014 - dice_coef: 0.6669 - val_loss: 0.0947 - val_dice_coef: 0.6772
# Epoch 247/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0937 - dice_coef: 0.6707 - val_loss: 0.0977 - val_dice_coef: 0.6749
# Epoch 248/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0967 - dice_coef: 0.6734 - val_loss: 0.0961 - val_dice_coef: 0.6722
# Epoch 249/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0986 - dice_coef: 0.6700 - val_loss: 0.0969 - val_dice_coef: 0.6794
# Epoch 250/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0984 - dice_coef: 0.6739 - val_loss: 0.0942 - val_dice_coef: 0.6830
# Epoch 251/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0940 - dice_coef: 0.6662 - val_loss: 0.1012 - val_dice_coef: 0.6565
# Epoch 252/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.1005 - dice_coef: 0.6723 - val_loss: 0.0944 - val_dice_coef: 0.6887
# Epoch 253/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0969 - dice_coef: 0.6717 - val_loss: 0.0975 - val_dice_coef: 0.6651
# Epoch 254/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1041 - dice_coef: 0.6691 - val_loss: 0.0944 - val_dice_coef: 0.6828
# Epoch 255/500
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0943 - dice_coef: 0.6730 - val_loss: 0.0984 - val_dice_coef: 0.6710
# Epoch 256/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0935 - dice_coef: 0.6716 - val_loss: 0.0965 - val_dice_coef: 0.6806
# Epoch 257/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0997 - dice_coef: 0.6733 - val_loss: 0.0955 - val_dice_coef: 0.6710
# Epoch 258/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0963 - dice_coef: 0.6664 - val_loss: 0.0970 - val_dice_coef: 0.6771
# Epoch 259/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0990 - dice_coef: 0.6766 - val_loss: 0.0951 - val_dice_coef: 0.6861
# Epoch 260/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0998 - dice_coef: 0.6723 - val_loss: 0.0986 - val_dice_coef: 0.6707
# Epoch 261/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0967 - dice_coef: 0.6766 - val_loss: 0.0935 - val_dice_coef: 0.6839
# Epoch 262/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0935 - dice_coef: 0.6707 - val_loss: 0.0970 - val_dice_coef: 0.6695
# Epoch 263/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0953 - dice_coef: 0.6734 - val_loss: 0.0937 - val_dice_coef: 0.6879
# Epoch 264/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0981 - dice_coef: 0.6659 - val_loss: 0.1006 - val_dice_coef: 0.6573
# Epoch 265/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0972 - dice_coef: 0.6700 - val_loss: 0.0933 - val_dice_coef: 0.6914
# Epoch 266/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1018 - dice_coef: 0.6821 - val_loss: 0.1016 - val_dice_coef: 0.6644
# Epoch 267/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0988 - dice_coef: 0.6695 - val_loss: 0.0935 - val_dice_coef: 0.6808
# Epoch 268/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0969 - dice_coef: 0.6651 - val_loss: 0.1014 - val_dice_coef: 0.6595
# Epoch 269/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0962 - dice_coef: 0.6646 - val_loss: 0.0941 - val_dice_coef: 0.6775
# Epoch 270/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0978 - dice_coef: 0.6691 - val_loss: 0.0955 - val_dice_coef: 0.6806
# Epoch 271/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0954 - dice_coef: 0.6734 - val_loss: 0.0970 - val_dice_coef: 0.6746
# Epoch 272/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1011 - dice_coef: 0.6713 - val_loss: 0.0955 - val_dice_coef: 0.6714
# Epoch 273/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1016 - dice_coef: 0.6724 - val_loss: 0.0967 - val_dice_coef: 0.6786
# Epoch 274/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0963 - dice_coef: 0.6777 - val_loss: 0.0952 - val_dice_coef: 0.6785
# Epoch 275/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0964 - dice_coef: 0.6725 - val_loss: 0.0966 - val_dice_coef: 0.6753
# Epoch 276/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.1039 - dice_coef: 0.6745 - val_loss: 0.0986 - val_dice_coef: 0.6732
# Epoch 277/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1003 - dice_coef: 0.6726 - val_loss: 0.0921 - val_dice_coef: 0.6849
# Epoch 278/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0973 - dice_coef: 0.6667 - val_loss: 0.1018 - val_dice_coef: 0.6593
# Epoch 279/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0976 - dice_coef: 0.6639 - val_loss: 0.0932 - val_dice_coef: 0.6857
# Epoch 280/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1047 - dice_coef: 0.6728 - val_loss: 0.1020 - val_dice_coef: 0.6617
# Epoch 281/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0999 - dice_coef: 0.6678 - val_loss: 0.0935 - val_dice_coef: 0.6839
# Epoch 282/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1045 - dice_coef: 0.6679 - val_loss: 0.0964 - val_dice_coef: 0.6726
# Epoch 283/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0981 - dice_coef: 0.6712 - val_loss: 0.0951 - val_dice_coef: 0.6776
# Epoch 284/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0937 - dice_coef: 0.6692 - val_loss: 0.0983 - val_dice_coef: 0.6684
# Epoch 285/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0948 - dice_coef: 0.6702 - val_loss: 0.0941 - val_dice_coef: 0.6835
# Epoch 286/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0981 - dice_coef: 0.6791 - val_loss: 0.0986 - val_dice_coef: 0.6760
# Epoch 287/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0972 - dice_coef: 0.6776 - val_loss: 0.0944 - val_dice_coef: 0.6797
# Epoch 288/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1004 - dice_coef: 0.6760 - val_loss: 0.0984 - val_dice_coef: 0.6717
# Epoch 289/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0992 - dice_coef: 0.6784 - val_loss: 0.0942 - val_dice_coef: 0.6857
# Epoch 290/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0986 - dice_coef: 0.6758 - val_loss: 0.0963 - val_dice_coef: 0.6721
# Epoch 291/500
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0956 - dice_coef: 0.6687 - val_loss: 0.0957 - val_dice_coef: 0.6793
# Epoch 292/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0952 - dice_coef: 0.6770 - val_loss: 0.0977 - val_dice_coef: 0.6772
# Epoch 293/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0885 - dice_coef: 0.6729 - val_loss: 0.0936 - val_dice_coef: 0.6783
# Epoch 294/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0937 - dice_coef: 0.6668 - val_loss: 0.1002 - val_dice_coef: 0.6713
# Epoch 295/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0923 - dice_coef: 0.6773 - val_loss: 0.0932 - val_dice_coef: 0.6852
# Epoch 296/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0960 - dice_coef: 0.6714 - val_loss: 0.1037 - val_dice_coef: 0.6545
# Epoch 297/500
# 4/4 [==============================] - 1s 382ms/step - loss: 0.0981 - dice_coef: 0.6705 - val_loss: 0.0932 - val_dice_coef: 0.6932
# Epoch 298/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1028 - dice_coef: 0.6737 - val_loss: 0.1001 - val_dice_coef: 0.6601
# Epoch 299/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0987 - dice_coef: 0.6636 - val_loss: 0.0945 - val_dice_coef: 0.6711
# Epoch 300/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0960 - dice_coef: 0.6692 - val_loss: 0.0987 - val_dice_coef: 0.6760
# Epoch 301/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0893 - dice_coef: 0.6754 - val_loss: 0.0932 - val_dice_coef: 0.6819
# Epoch 302/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.1002 - dice_coef: 0.6672 - val_loss: 0.1028 - val_dice_coef: 0.6616
# Epoch 303/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0944 - dice_coef: 0.6671 - val_loss: 0.0940 - val_dice_coef: 0.6867
# Epoch 304/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0991 - dice_coef: 0.6721 - val_loss: 0.0968 - val_dice_coef: 0.6726
# Epoch 305/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0984 - dice_coef: 0.6707 - val_loss: 0.0934 - val_dice_coef: 0.6783
# Epoch 306/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0930 - dice_coef: 0.6698 - val_loss: 0.0962 - val_dice_coef: 0.6793
# Epoch 307/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0908 - dice_coef: 0.6728 - val_loss: 0.0954 - val_dice_coef: 0.6773
# Epoch 308/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0959 - dice_coef: 0.6708 - val_loss: 0.0940 - val_dice_coef: 0.6747
# Epoch 309/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0937 - dice_coef: 0.6726 - val_loss: 0.0950 - val_dice_coef: 0.6841
# Epoch 310/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0972 - dice_coef: 0.6817 - val_loss: 0.0959 - val_dice_coef: 0.6786
# Epoch 311/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0951 - dice_coef: 0.6752 - val_loss: 0.0936 - val_dice_coef: 0.6787
# Epoch 312/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0937 - dice_coef: 0.6749 - val_loss: 0.0955 - val_dice_coef: 0.6777
# Epoch 313/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0944 - dice_coef: 0.6759 - val_loss: 0.0957 - val_dice_coef: 0.6756
# Epoch 314/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1036 - dice_coef: 0.6773 - val_loss: 0.0972 - val_dice_coef: 0.6808
# Epoch 315/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0919 - dice_coef: 0.6764 - val_loss: 0.0938 - val_dice_coef: 0.6814
# Epoch 316/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0997 - dice_coef: 0.6732 - val_loss: 0.0973 - val_dice_coef: 0.6747
# Epoch 317/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0964 - dice_coef: 0.6753 - val_loss: 0.0943 - val_dice_coef: 0.6841
# Epoch 318/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0923 - dice_coef: 0.6797 - val_loss: 0.0973 - val_dice_coef: 0.6740
# Epoch 319/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0913 - dice_coef: 0.6704 - val_loss: 0.0945 - val_dice_coef: 0.6743
# Epoch 320/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0997 - dice_coef: 0.6784 - val_loss: 0.0972 - val_dice_coef: 0.6848
# Epoch 321/500
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0945 - dice_coef: 0.6799 - val_loss: 0.0935 - val_dice_coef: 0.6735
# Epoch 322/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0973 - dice_coef: 0.6693 - val_loss: 0.1012 - val_dice_coef: 0.6709
# Epoch 323/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1042 - dice_coef: 0.6827 - val_loss: 0.0931 - val_dice_coef: 0.6852
# Epoch 324/500
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1002 - dice_coef: 0.6694 - val_loss: 0.0982 - val_dice_coef: 0.6668
# Epoch 325/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0978 - dice_coef: 0.6739 - val_loss: 0.0956 - val_dice_coef: 0.6772
# Epoch 326/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0993 - dice_coef: 0.6778 - val_loss: 0.0994 - val_dice_coef: 0.6687
# Epoch 327/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0945 - dice_coef: 0.6741 - val_loss: 0.0943 - val_dice_coef: 0.6787
# Epoch 328/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0978 - dice_coef: 0.6711 - val_loss: 0.0993 - val_dice_coef: 0.6678
# Epoch 329/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0973 - dice_coef: 0.6781 - val_loss: 0.0942 - val_dice_coef: 0.6852
# Epoch 330/500
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0945 - dice_coef: 0.6734 - val_loss: 0.0975 - val_dice_coef: 0.6698
# Epoch 331/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0915 - dice_coef: 0.6694 - val_loss: 0.0948 - val_dice_coef: 0.6826
# Epoch 332/500
# ...
# Epoch 391/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0980 - dice_coef: 0.6734 - val_loss: 0.1002 - val_dice_coef: 0.6606
# Epoch 392/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0931 - dice_coef: 0.6677 - val_loss: 0.0930 - val_dice_coef: 0.6910
# Epoch 393/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0970 - dice_coef: 0.6780 - val_loss: 0.0993 - val_dice_coef: 0.6724
# Epoch 394/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1007 - dice_coef: 0.6681 - val_loss: 0.0923 - val_dice_coef: 0.6775
# Epoch 395/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0997 - dice_coef: 0.6617 - val_loss: 0.1038 - val_dice_coef: 0.6591
# Epoch 396/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1002 - dice_coef: 0.6776 - val_loss: 0.0940 - val_dice_coef: 0.6813
# Epoch 397/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0981 - dice_coef: 0.6599 - val_loss: 0.0954 - val_dice_coef: 0.6700
# Epoch 398/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0931 - dice_coef: 0.6737 - val_loss: 0.0931 - val_dice_coef: 0.6929
# Epoch 399/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0928 - dice_coef: 0.6770 - val_loss: 0.0974 - val_dice_coef: 0.6700
# Epoch 400/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0947 - dice_coef: 0.6695 - val_loss: 0.0941 - val_dice_coef: 0.6784
# Epoch 401/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0967 - dice_coef: 0.6694 - val_loss: 0.0988 - val_dice_coef: 0.6709
# Epoch 402/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1003 - dice_coef: 0.6751 - val_loss: 0.0932 - val_dice_coef: 0.6895
# Epoch 403/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0995 - dice_coef: 0.6747 - val_loss: 0.1019 - val_dice_coef: 0.6637
# Epoch 404/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0948 - dice_coef: 0.6722 - val_loss: 0.0923 - val_dice_coef: 0.6881
# Epoch 405/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0974 - dice_coef: 0.6775 - val_loss: 0.1005 - val_dice_coef: 0.6659
# Epoch 406/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0949 - dice_coef: 0.6729 - val_loss: 0.0923 - val_dice_coef: 0.6831
# Epoch 407/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0913 - dice_coef: 0.6718 - val_loss: 0.1003 - val_dice_coef: 0.6664
# Epoch 408/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1017 - dice_coef: 0.6714 - val_loss: 0.0928 - val_dice_coef: 0.6858
# Epoch 409/500
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0974 - dice_coef: 0.6695 - val_loss: 0.0986 - val_dice_coef: 0.6671
# Epoch 410/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0929 - dice_coef: 0.6638 - val_loss: 0.0939 - val_dice_coef: 0.6872
# Epoch 411/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0986 - dice_coef: 0.6769 - val_loss: 0.0965 - val_dice_coef: 0.6798
# Epoch 412/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1016 - dice_coef: 0.6724 - val_loss: 0.0968 - val_dice_coef: 0.6708
# Epoch 413/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0915 - dice_coef: 0.6665 - val_loss: 0.0940 - val_dice_coef: 0.6704
# Epoch 414/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0999 - dice_coef: 0.6737 - val_loss: 0.1001 - val_dice_coef: 0.6781
# Epoch 415/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0976 - dice_coef: 0.6815 - val_loss: 0.0966 - val_dice_coef: 0.6769
# Epoch 416/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0971 - dice_coef: 0.6719 - val_loss: 0.0943 - val_dice_coef: 0.6708
# Epoch 417/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0978 - dice_coef: 0.6708 - val_loss: 0.1001 - val_dice_coef: 0.6734
# Epoch 418/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0943 - dice_coef: 0.6781 - val_loss: 0.0945 - val_dice_coef: 0.6811
# Epoch 419/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0941 - dice_coef: 0.6692 - val_loss: 0.0967 - val_dice_coef: 0.6675
# Epoch 420/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0954 - dice_coef: 0.6718 - val_loss: 0.0919 - val_dice_coef: 0.6861
# Epoch 421/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0941 - dice_coef: 0.6638 - val_loss: 0.1001 - val_dice_coef: 0.6600
# Epoch 422/500
# 4/4 [==============================] - 1s 377ms/step - loss: 0.1024 - dice_coef: 0.6679 - val_loss: 0.0931 - val_dice_coef: 0.6948
# Epoch 423/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1010 - dice_coef: 0.6721 - val_loss: 0.0972 - val_dice_coef: 0.6573
# Epoch 424/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.1017 - dice_coef: 0.6595 - val_loss: 0.0930 - val_dice_coef: 0.6789
# Epoch 425/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.1009 - dice_coef: 0.6674 - val_loss: 0.0961 - val_dice_coef: 0.6787
# Epoch 426/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0958 - dice_coef: 0.6749 - val_loss: 0.0958 - val_dice_coef: 0.6768
# Epoch 427/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0948 - dice_coef: 0.6690 - val_loss: 0.0926 - val_dice_coef: 0.6829
# Epoch 428/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0995 - dice_coef: 0.6694 - val_loss: 0.0997 - val_dice_coef: 0.6686
# Epoch 429/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0924 - dice_coef: 0.6695 - val_loss: 0.0932 - val_dice_coef: 0.6803
# Epoch 430/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0917 - dice_coef: 0.6673 - val_loss: 0.0953 - val_dice_coef: 0.6700
# Epoch 431/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0953 - dice_coef: 0.6702 - val_loss: 0.0919 - val_dice_coef: 0.6880
# Epoch 432/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0941 - dice_coef: 0.6738 - val_loss: 0.0940 - val_dice_coef: 0.6814
# Epoch 433/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0925 - dice_coef: 0.6649 - val_loss: 0.0977 - val_dice_coef: 0.6648
# Epoch 434/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0973 - dice_coef: 0.6708 - val_loss: 0.0926 - val_dice_coef: 0.6854
# Epoch 435/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0956 - dice_coef: 0.6805 - val_loss: 0.0965 - val_dice_coef: 0.6793
# Epoch 436/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0965 - dice_coef: 0.6794 - val_loss: 0.0933 - val_dice_coef: 0.6849
# Epoch 437/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.1006 - dice_coef: 0.6753 - val_loss: 0.1040 - val_dice_coef: 0.6590
# Epoch 438/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0964 - dice_coef: 0.6722 - val_loss: 0.0922 - val_dice_coef: 0.6875
# Epoch 439/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1041 - dice_coef: 0.6761 - val_loss: 0.1027 - val_dice_coef: 0.6599
# Epoch 440/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0917 - dice_coef: 0.6652 - val_loss: 0.0917 - val_dice_coef: 0.6790
# Epoch 441/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0977 - dice_coef: 0.6649 - val_loss: 0.1003 - val_dice_coef: 0.6651
# Epoch 442/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0968 - dice_coef: 0.6734 - val_loss: 0.0947 - val_dice_coef: 0.6876
# Epoch 443/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.1063 - dice_coef: 0.6693 - val_loss: 0.0959 - val_dice_coef: 0.6665
# Epoch 444/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.1030 - dice_coef: 0.6653 - val_loss: 0.0945 - val_dice_coef: 0.6849
# Epoch 445/500
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0978 - dice_coef: 0.6743 - val_loss: 0.0962 - val_dice_coef: 0.6754
# Epoch 446/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0954 - dice_coef: 0.6709 - val_loss: 0.0980 - val_dice_coef: 0.6678
# Epoch 447/500
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0969 - dice_coef: 0.6687 - val_loss: 0.0931 - val_dice_coef: 0.6856
# Epoch 448/500
# 4/4 [==============================] - 1s 299ms/step - loss: 0.0909 - dice_coef: 0.6724 - val_loss: 0.0945 - val_dice_coef: 0.6769
# Epoch 449/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0954 - dice_coef: 0.6744 - val_loss: 0.0949 - val_dice_coef: 0.6881
# Epoch 450/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0936 - dice_coef: 0.6773 - val_loss: 0.0943 - val_dice_coef: 0.6745
# Epoch 451/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1021 - dice_coef: 0.6677 - val_loss: 0.0965 - val_dice_coef: 0.6772
# Epoch 452/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0900 - dice_coef: 0.6832 - val_loss: 0.0936 - val_dice_coef: 0.6917
# Epoch 453/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0970 - dice_coef: 0.6762 - val_loss: 0.0966 - val_dice_coef: 0.6651
# Epoch 454/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0906 - dice_coef: 0.6678 - val_loss: 0.0938 - val_dice_coef: 0.6838
# Epoch 455/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0976 - dice_coef: 0.6810 - val_loss: 0.0974 - val_dice_coef: 0.6767
# Epoch 456/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0910 - dice_coef: 0.6709 - val_loss: 0.0928 - val_dice_coef: 0.6801
# Epoch 457/500
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1006 - dice_coef: 0.6678 - val_loss: 0.0994 - val_dice_coef: 0.6733
# Epoch 458/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0991 - dice_coef: 0.6707 - val_loss: 0.0941 - val_dice_coef: 0.6813
# Epoch 459/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0891 - dice_coef: 0.6725 - val_loss: 0.0946 - val_dice_coef: 0.6711
# Epoch 460/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0972 - dice_coef: 0.6645 - val_loss: 0.0967 - val_dice_coef: 0.6723
# Epoch 461/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0946 - dice_coef: 0.6721 - val_loss: 0.0952 - val_dice_coef: 0.6833
# Epoch 462/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1004 - dice_coef: 0.6755 - val_loss: 0.0965 - val_dice_coef: 0.6788
# Epoch 463/500
# 4/4 [==============================] - 1s 298ms/step - loss: 0.1016 - dice_coef: 0.6679 - val_loss: 0.0997 - val_dice_coef: 0.6602
# Epoch 464/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1007 - dice_coef: 0.6716 - val_loss: 0.0974 - val_dice_coef: 0.6739
# Epoch 465/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1067 - dice_coef: 0.6674 - val_loss: 0.0947 - val_dice_coef: 0.6762
# Epoch 466/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0976 - dice_coef: 0.6713 - val_loss: 0.0947 - val_dice_coef: 0.6790
# Epoch 467/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0947 - dice_coef: 0.6718 - val_loss: 0.0967 - val_dice_coef: 0.6704
# Epoch 468/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0945 - dice_coef: 0.6732 - val_loss: 0.0941 - val_dice_coef: 0.6856
# Epoch 469/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0975 - dice_coef: 0.6771 - val_loss: 0.0964 - val_dice_coef: 0.6804
# Epoch 470/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0955 - dice_coef: 0.6787 - val_loss: 0.0934 - val_dice_coef: 0.6865
# Epoch 471/500
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0999 - dice_coef: 0.6756 - val_loss: 0.0968 - val_dice_coef: 0.6765
# Epoch 472/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0969 - dice_coef: 0.6762 - val_loss: 0.0947 - val_dice_coef: 0.6833
# Epoch 473/500
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0981 - dice_coef: 0.6762 - val_loss: 0.0971 - val_dice_coef: 0.6738
# Epoch 474/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0946 - dice_coef: 0.6731 - val_loss: 0.0957 - val_dice_coef: 0.6752
# Epoch 475/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0929 - dice_coef: 0.6763 - val_loss: 0.0950 - val_dice_coef: 0.6866
# Epoch 476/500
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0964 - dice_coef: 0.6783 - val_loss: 0.0964 - val_dice_coef: 0.6746
# Epoch 477/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.1006 - dice_coef: 0.6771 - val_loss: 0.0962 - val_dice_coef: 0.6833
# Epoch 478/500
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0936 - dice_coef: 0.6802 - val_loss: 0.0943 - val_dice_coef: 0.6793
# Epoch 479/500
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0940 - dice_coef: 0.6750 - val_loss: 0.0960 - val_dice_coef: 0.6823
# Epoch 480/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0976 - dice_coef: 0.6815 - val_loss: 0.0955 - val_dice_coef: 0.6827
# Epoch 481/500
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0932 - dice_coef: 0.6768 - val_loss: 0.0956 - val_dice_coef: 0.6770
# Epoch 482/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0907 - dice_coef: 0.6768 - val_loss: 0.0951 - val_dice_coef: 0.6803
# Epoch 483/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0991 - dice_coef: 0.6792 - val_loss: 0.0947 - val_dice_coef: 0.6833
# Epoch 484/500
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0950 - dice_coef: 0.6808 - val_loss: 0.0979 - val_dice_coef: 0.6769
# Epoch 485/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0987 - dice_coef: 0.6787 - val_loss: 0.0944 - val_dice_coef: 0.6832
# Epoch 486/500
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1014 - dice_coef: 0.6801 - val_loss: 0.0986 - val_dice_coef: 0.6739
# Epoch 487/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0912 - dice_coef: 0.6747 - val_loss: 0.0933 - val_dice_coef: 0.6792
# Epoch 488/500
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0968 - dice_coef: 0.6761 - val_loss: 0.0988 - val_dice_coef: 0.6790
# Epoch 489/500
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0985 - dice_coef: 0.6803 - val_loss: 0.0940 - val_dice_coef: 0.6793
# Epoch 490/500
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0939 - dice_coef: 0.6743 - val_loss: 0.0931 - val_dice_coef: 0.6808
# Epoch 491/500
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0936 - dice_coef: 0.6753 - val_loss: 0.0981 - val_dice_coef: 0.6752
# Epoch 492/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1025 - dice_coef: 0.6764 - val_loss: 0.0937 - val_dice_coef: 0.6838
# Epoch 493/500
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0964 - dice_coef: 0.6810 - val_loss: 0.0970 - val_dice_coef: 0.6771
# Epoch 494/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0945 - dice_coef: 0.6800 - val_loss: 0.0936 - val_dice_coef: 0.6820
# Epoch 495/500
# 4/4 [==============================] - 1s 300ms/step - loss: 0.0939 - dice_coef: 0.6751 - val_loss: 0.0961 - val_dice_coef: 0.6786
# Epoch 496/500
# 4/4 [==============================] - 1s 306ms/step - loss: 0.1002 - dice_coef: 0.6803 - val_loss: 0.0971 - val_dice_coef: 0.6746
# Epoch 497/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.1018 - dice_coef: 0.6782 - val_loss: 0.0934 - val_dice_coef: 0.6784
# Epoch 498/500
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0938 - dice_coef: 0.6738 - val_loss: 0.0970 - val_dice_coef: 0.6750
# Epoch 499/500
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0914 - dice_coef: 0.6792 - val_loss: 0.0931 - val_dice_coef: 0.6854
# Epoch 500/500
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0998 - dice_coef: 0.6771 - val_loss: 0.1006 - val_dice_coef: 0.6601

# %%
history = logs.history
val_score = history['val_dice_coef']
max_val_score = max(val_score)
max_val_epochs = val_score.index(max_val_score)+1
print( 'Best val score : ' + str(max_val_score) )
print( 'Best val epoch : ' + str(max_val_epochs) )
# Out:
# Best val score : 0.6889401078224182
# Best val epoch : 412

# %%
history = logs.history
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('loss')
plt.savefig('/content/drive/MyDrive/seg_loss.png')

# %%
plt.plot(history['dice_coef'])
plt.plot(history['val_dice_coef'])
plt.title('Dice')
plt.savefig('/content/drive/MyDrive/seg_Dice.png')

# %%
model_final = models.load_model('/content/drive/MyDrive/seg.h5', compile=False)

# %%
# Sample 1 batch
batch_idx = np.random.randint(len(val_gen))
print(batch_idx)
data = val_gen[batch_idx]
imgs, mask = data # (bs, 512, 512, 3), (bs, 512, 512, 1)
mask_pred = model_final.predict(imgs)

# show inputs
img_idx = np.random.randint(len(imgs)) # sample 1 image from batch
plt.figure(figsize=(20, 5))
plt.subplot(1,3,1)
plt.imshow(imgs[img_idx])

# show ground truth & model prediction
plt.subplot(1, 3, 2)
plt.imshow(mask[img_idx, :, :, 0])
plt.subplot(1, 3, 3)
plt.imshow(mask_pred[img_idx, :, :, 0])
plt.show()
# plt.imshow(mask_pred[img_idx, :, :, 0], cmap='gray')
# Out:
# 0

# %%
# Displayed with different threshold
mask_pred_raw = mask_pred[img_idx, :, :, 0]
mask_pred_raw
# Out:
# array([[1.14527703e-08, 1.24243726e-08, 2.33984352e-08, ...,
#         1.39090986e-07, 1.55935629e-06, 1.29549022e-04],
#        [1.01214441e-08, 1.61175144e-08, 3.77739440e-08, ...,
#         1.69484750e-07, 1.94526160e-06, 1.28358253e-04],
#        [5.99491612e-09, 1.20741310e-08, 2.90891791e-08, ...,
#         1.05832406e-07, 1.54535303e-06, 9.15310011e-05],
#        ...,
#        [6.74304301e-09, 6.68092781e-09, 4.77763162e-09, ...,
#         5.27969171e-08, 4.63743930e-07, 3.58935322e-05],
#        [3.58587364e-08, 4.66744972e-08, 4.61946499e-08, ...,
#         8.99384190e-07, 5.08203539e-06, 2.00634619e-04],
#        [5.40890687e-05, 4.67381760e-05, 3.73043440e-05, ...,
#         1.60642448e-04, 4.53351007e-04, 4.32358962e-03]], dtype=float32)

# %%
plt.imshow(mask[img_idx, :, :, 0])
plt.title('Ground Truth')
plt.show()

plt.figure(figsize=(20, 10))
for i in range(1, 10):
    plt.subplot(2, 5, i)
    threshold = i * 0.1
    mask_threshold = mask_pred_raw.copy()
    mask_threshold[mask_threshold <= threshold] = 0.
    mask_threshold[mask_threshold > threshold] = 1.
    plt.imshow(mask_threshold)
    plt.title(f'threshold: {threshold:.1f}')
plt.show()

# %%
# make prediction
threshold = 0.4
outputs = []
for i in range(len(test_gen)):
    x_test = test_gen[i]
    y_preds = model_final.predict(x_test)
    y_preds[y_preds <= threshold] = 0
    y_preds[y_preds > threshold] = 1
    for y_pred in y_preds:
        dots = np.where(y_pred.flatten() == 1)[0]
        run_lengths = []
        prev = -2
        for b in dots:
            if (b > prev +1):
                run_lengths.extend((b+1,0))
            run_lengths[-1] += 1
            prev = b
        output = ' '.join([str(r) for r in run_lengths])
        outputs.append(output)

# %%
df = pd.DataFrame(columns=['Id', 'Predicted'])
df['Id'] = [str(i) for i in range(20)]
df['Predicted'] = outputs
df.to_csv('/content/drive/MyDrive/seg_submission.csv', index=None)
df
# Out:
#     Id                                          Predicted
# 0    0  14083 6 14570 2 14596 5 15079 5 15105 11 15140...
# 1    1  15103 4 15615 5 16127 6 16145 2 16640 6 16657 ...
# 2    2  12556 3 13068 1 15566 4 15621 3 16078 4 16130 ...
# 3    3  13047 5 13559 5 14071 5 14584 5 15096 5 15609 ...
# 4    4  16676 3 17187 5 17698 6 18173 2 18210 6 18683 ...
# 5    5  17189 5 17701 7 18117 3 18213 7 18628 4 18725 ...
# 6    6  15591 2 16096 2 16103 2 16609 10 16655 3 17121...
# 7    7  14568 2 15079 4 15591 5 15635 2 16104 4 16146 ...
# 8    8  14615 3 15090 1 15126 5 15602 3 15608 3 15634 ...
# 9    9  15615 3 16128 2 16601 5 16640 2 17113 4 17152 ...
# 10  10  16090 9 16592 20 17102 21 17613 21 18123 20 18...
# 11  11  14569 3 15079 5 15129 2 15591 6 15639 4 16102 ...
# 12  12  15625 1 16136 3 16157 3 16607 3 16648 4 16668 ...
# 13  13  12569 2 13081 6 13594 4 14105 6 14545 4 14618 ...
# 14  14  15113 1 15581 6 15624 3 15641 3 16093 5 16135 ...
# 15  15  15113 4 15625 7 16137 9 16651 7 16682 4 17165 ...
# 16  16  18658 2 19169 3 19681 3 20193 3 20705 3 21169 ...
# 17  17  15108 3 15620 3 16128 8 16640 8 17152 6 17662 ...
# 18  18  14593 2 15104 5 15617 4 16129 4 16617 1 16639 ...
# 19  19  17134 2 17645 5 17652 3 18121 1 18157 10 18631...
